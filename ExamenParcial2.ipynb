# %% [markdown]
# <a href="https://colab.research.google.com/github/alangilsanchez/MineriaDeDatos/blob/main/ExamenParcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("ventas.csv", parse_dates=["fecha"])
df = df.set_index("fecha")

print(df.head(3))
print(df.info())
